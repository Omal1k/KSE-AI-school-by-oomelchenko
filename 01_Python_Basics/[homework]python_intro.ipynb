# %% [markdown]
# <p style="align: center;"><img align=center src="https://s8.hostingkartinok.com/uploads/images/2018/08/308b49fcfbc619d629fe4604bceb67ac.jpg" width=500 height=450/></p>
#
# <h3 style="text-align: center;"><b>Deep Learning course</b></h3>
#
# <h2 style="text-align: center;"><b>Домашнє завдання. Основи Python</b></h2>
#
# Для самостійного виконання пропонується нижче наведений набір завдань, які треба буде здавати через github classsroom

# %% [markdown]
# ### Подвійний факторіал
# Дано натуральне $N \leqslant 100$.  Знайдіть добуток всіх парних натуральних чисел, які не більше за $N$.

# %%
N = 10

def fact():
    '''your code'''
    pass

#answer - 3840

# %% [markdown]
# ### Сортування, лямда
#
# Нехай у вас є список, в якому елменти - tuple з рядків:
#
# ``items = [('Ighor', 'beta'), ('Oksana', 'alpha'), ('Lev', 'gamma'), ('Illya', 'epsilon')]``
#
# Вам потрібно відсортувати цей список за останньою буквоб другого елементу кожного ``tuple``, на виході маєте отримати наступний список:
#
# ``sorted_items = [('Oksana', 'alpha'), ('Ighor', 'beta'), ('Illya', 'epsilon'), ('Lev', 'gamma')]``.
#
# Що потрібно вставити замість "###"" у коді, який наведено нижче, для вирішення задачі?
#
# ``sorted_items = sorted(items, key=lambda x: ###)``

# %%
items = [('Ighor', 'beta'), ('Oksana', 'alpha'), ('Lev', 'gamma'), ('Illya', 'epsilon')]

sorted_items = sorted(items, key=lambda x: <YOUR CODE>)

# %% [markdown]
# ### Слайси
#
# Дано код:
#
# ``x = [1, 2, 3, 4, 5]``
#
# ``x[###] = [-1, -3, -5]``
#
# ``print(x)``
#
# Напишіть слайс замість ###, щоб отримати наступний вигляд списку:
#
# ``[-5, 2, -3, 4, -1]``

# %%
x = [1, 2, 3, 4, 5]
x[<YOUR CODE>] = [-1, -3, -5]

# %% [markdown]
# ### Масиви
# Дано масив $A[0,\ldots,N-1]$. Напишіть функцію, вона приймає один обов'язковий аргумент A і опційний аргумент ``erase``, за замовчування він дорівнює 1. Поверніть масив $B[0,\ldots, N-1]$, где $B_i = A_0 + \ldots + A_{i}$ --- масив часткових сум масиву $A$, та видалити всі елменти з масиву $B$, які дорівнюють ``erase``. Намагайтесь зробити цю задачу за лінійний час(Big O notation) і без використовування Numpy.

# %%
def cumsum_and_erase(<YOUR CODE>):
    #YOUR CODE
    
    B = #YOUR CODE
    return B

A = [5, 1, 4, 5, 14]
B = cumsum_and_erase(A, erase=10)

assert B == [5, 6, 15, 29], "Something is wrong! Please try again"

# %% [markdown]
# ### Оброка тексту
# Дано список текстів, слова розділені пробілами (можно рахувати, що знаки пунктуації відсутні). Частина слів є сміттям: в них є цифри і спец.символи. Відфільтруйте такі слова з кожного тексту. Не забувайте про методи: ``str.split``, ``str.isalpha``, ``str.join``, а також [генератор filter](http://pythonicway.com/python-functinal-programming).

# %%
sentences = ['1 thousand devils', 'My name is 9Pasha', 'Room #125 costs $100']

def process(sentences):
    #YOUR CODE
    
    result = #YOUR CODE
    return result

assert process(sentences) == ['thousand devils', 'My name is', 'Room costs'], \
"Something is wrong! Please try again"

# %% [markdown]
# ### Перша "Нейромережа", класи, ооп
# Реалізуйте клас "Neuron", у якого будуть наступні методи:
#
# * ``__init__``. Приймає на вхід масив ваг нейрона --- $w = (w_1, \ldots, w_n)$, а також функцію активації $f$ (за замовчуванням $f(x) = x$). Зберігає всі ваги і функцію всередині класу.
#
# * ``forward``. Приймає на вхід масив $x = (x_1, \ldots, x_N)$ --- входи нейрону. Повертає $f(w_1x_1 + \ldots + w_nx_n)$.
#
# * ``backlog``. Повертає останній масив $x$, який йшов фкнкції ``forward`` на вхід.

# %%
class Neuron:
    
    def __init__(self, w, f = lambda x: x):
        #YOUR CODE HERE
    
    def forward(self, x):
        #YOUR CODE HERE
        
    def backlog(self):
        #YOUR CODE HERE

# %%
import math

w = [0.5, 1., -1., 2.]

neuron = Neuron([0.5, 1., -1., 2.], lambda x: 1. / (1 + math.exp(x)))

x = [1, 2, 3, 4]

assert abs(neuron.forward(x) - 0.0005527) < 1e-6, "Something is wrong! Please try again"

assert neuron.backlog() == x, "Something is wrong! Please try again"

y = [0, 0, 0, 0]

assert abs(neuron.forward(y) - 0.5) < 1e-6, "Something is wrong! Please try again"
